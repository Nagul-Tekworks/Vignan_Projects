# %% [markdown]
# # pETROL DATE ANALYSIS

# %% [markdown]
# Which distributor has the highest average buy rate?
#
# Which distributor has the highest average sell rate?
#
# How has the buy rate changed over the years for each distributor?
#
# How has the sell rate changed over the years for each distributor?
#
# Which year recorded the highest total sales volume (volume OUT)?
#
# Which year recorded the lowest total production volume (volume IN)?
#
# What is the profit margin (Sell rate – Buy rate) for each distributor?
#
# Which distributor has the highest total profit across all years?
#
# Which distributor has the highest efficiency (volume OUT / volume IN)?
#
# Is there a correlation between buy rate and sell rate?
#
# Is there a correlation between volume IN and volume OUT?
#
# Which year shows the largest difference between volume IN and OUT?
#
# How does the performance of Shell compare with Bharat over the years?
#
# What is the overall growth trend in sell rates over the years?
#
# Are any distributors showing a decline in volume OUT over time?
#
# Which distributor has maintained the most stable buy and sell rates?
#
# What is the total revenue generated by each distributor over the entire period?
#
# Which year had the highest overall revenue across all distributors?
#
# Which distributor achieved the best average profit-to-volume ratio?
#
# Are there any years where buy rates increased but sell rates decreased?
#
# How do Hindustan’s volumes compare to Shell’s volumes annually?
#
# Which distributor appears to have the most consistent supply (volume IN close to volume OUT)?
#
# Are there any patterns indicating operational inefficiency (large gaps between IN and OUT)?
#
# What is the overall average buy and sell rate across all distributors?
#
# If a new distributor enters the market, what should be the target average buy and sell rates to stay competitive?
#
# How much total volume (IN and OUT) did each distributor handle across all years?
#
# Which distributor contributed the most to total sell volume in the latest year?
#
# Are profits increasing with higher volumes or higher rates?
#
# What is the year-over-year percentage growth in sell rate for each distributor?
#
# Based on trends, which distributor is likely to dominate the market in the next few years?
